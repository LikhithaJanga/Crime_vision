# %% [markdown]
# ### ***Task 1***

# %%
import pandas as pd
import numpy as np

# %%
a = pd.Series(np.random.rand(4))
b = pd.Series(np.random.rand(4))
c = pd.Series(np.random.rand(4))
d = pd.Series(np.random.rand(4))
df = pd.DataFrame([a,b,c,d])
df
# Out:
#           0         1         2         3
# 0  0.182465  0.092363  0.948628  0.788995
# 1  0.156619  0.719297  0.722733  0.448287
# 2  0.967874  0.738129  0.439907  0.487001
# 3  0.276758  0.864783  0.650011  0.420981

# %% [markdown]
# ### ***Task 2***

# %%
df.columns=['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.182465        0.092363        0.948628        0.788995
# 1        0.156619        0.719297        0.722733        0.448287
# 2        0.967874        0.738129        0.439907        0.487001
# 3        0.276758        0.864783        0.650011        0.420981

# %% [markdown]
# ### ***Task3***

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.395929        0.603643        0.690320        0.536316
# std          0.384777        0.346921        0.209845        0.170617
# min          0.156619        0.092363        0.439907        0.420981
# 25%          0.176004        0.562563        0.597485        0.441460
# 50%          0.229612        0.728713        0.686372        0.467644
# 75%          0.449537        0.769792        0.779207        0.562499
# max          0.967874        0.864783        0.948628        0.788995

# %% [markdown]
# ### ***Task 4***

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      float64
#  1   Random value 2  4 non-null      float64
#  2   Random value 3  4 non-null      float64
#  3   Random value 4  4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes

# %% [markdown]
# ### ***Task 5***

# %%
df.loc[0:3,'Random value 2':'Random value 3']
# Out:
#    Random value 2  Random value 3
# 0        0.092363        0.948628
# 1        0.719297        0.722733
# 2        0.738129        0.439907
# 3        0.864783        0.650011

# %%
df.iloc[0:,[1,2]]
# Out:
#    Random value 2  Random value 3
# 0        0.092363        0.948628
# 1        0.719297        0.722733
# 2        0.738129        0.439907
# 3        0.864783        0.650011

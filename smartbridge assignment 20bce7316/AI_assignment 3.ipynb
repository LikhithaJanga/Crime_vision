# %% [markdown]
# ### ***Importing and Data Preprocessing***

# %%
# Data Augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# CNN

from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Flatten,Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Dropout

# %%
train_gen = ImageDataGenerator(rescale=(1./255),horizontal_flip=True,shear_range=0.2)
test_gen = ImageDataGenerator(rescale=(1./255))  #--> (0 to 255) convert to (0 to 1)

# %%
train = train_gen.flow_from_directory('/content/drive/MyDrive/ds_bird/train_data/train_data',target_size=(120, 120),class_mode='categorical', batch_size=8)
test = test_gen.flow_from_directory('/content/drive/MyDrive/ds_bird/test_data/test_data',target_size=(120, 120),class_mode='categorical', batch_size=8)
# Out:
# Found 150 images belonging to 16 classes.
# Found 157 images belonging to 16 classes.

# %% [markdown]
# ### ***CNN***

# %%
model = Sequential([
    Convolution2D(20,(3,3),activation = 'relu',input_shape=(120,120,3)),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(45,activation = 'relu'),
    Dense(16,activation = 'softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 118, 118, 20)      560
#
#  max_pooling2d_16 (MaxPoolin  (None, 59, 59, 20)       0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 69620)             0
#
#  dense_24 (Dense)            (None, 45)                3132945
#
#  dense_25 (Dense)            (None, 16)                736
#
# =================================================================
# Total params: 3,134,241
# Trainable params: 3,134,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
train.class_indices
# Out:
# {'blasti': 0,
#  'bonegl': 1,
#  'brhkyt': 2,
#  'cbrtsh': 3,
#  'cmnmyn': 4,
#  'gretit': 5,
#  'hilpig': 6,
#  'himbul': 7,
#  'himgri': 8,
#  'hsparo': 9,
#  'indvul': 10,
#  'jglowl': 11,
#  'lbicrw': 12,
#  'mgprob': 13,
#  'rebimg': 14,
#  'wcrsrt': 15}

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='categorical_crossentropy')

# %%
model_fit = model.fit(train,epochs =20,
                     validation_data = test ,batch_size=5)
# Out:
# Epoch 1/20
# 19/19 [==============================] - 118s 6s/step - loss: 4.6438 - accuracy: 0.1133 - val_loss: 2.7846 - val_accuracy: 0.1338
# Epoch 2/20
# 19/19 [==============================] - 72s 4s/step - loss: 2.6900 - accuracy: 0.1667 - val_loss: 2.6769 - val_accuracy: 0.0955
# Epoch 3/20
# 19/19 [==============================] - 70s 4s/step - loss: 2.5767 - accuracy: 0.1600 - val_loss: 2.7391 - val_accuracy: 0.0764
# Epoch 4/20
# 19/19 [==============================] - 71s 4s/step - loss: 2.3777 - accuracy: 0.2333 - val_loss: 2.5970 - val_accuracy: 0.1401
# Epoch 5/20
# 19/19 [==============================] - 70s 4s/step - loss: 2.3058 - accuracy: 0.2733 - val_loss: 2.5855 - val_accuracy: 0.1401
# Epoch 6/20
# 19/19 [==============================] - 75s 4s/step - loss: 2.1122 - accuracy: 0.3400 - val_loss: 2.6759 - val_accuracy: 0.1401
# Epoch 7/20
# 19/19 [==============================] - 71s 4s/step - loss: 1.9980 - accuracy: 0.3733 - val_loss: 2.6177 - val_accuracy: 0.1911
# Epoch 8/20
# 19/19 [==============================] - 71s 4s/step - loss: 1.8097 - accuracy: 0.4267 - val_loss: 2.7303 - val_accuracy: 0.2038
# Epoch 9/20
# 19/19 [==============================] - 70s 4s/step - loss: 1.6780 - accuracy: 0.4933 - val_loss: 2.7163 - val_accuracy: 0.1529
# Epoch 10/20
# 19/19 [==============================] - 72s 4s/step - loss: 1.5353 - accuracy: 0.4733 - val_loss: 2.7460 - val_accuracy: 0.1210
# Epoch 11/20
# 19/19 [==============================] - 70s 4s/step - loss: 1.4395 - accuracy: 0.5800 - val_loss: 2.9142 - val_accuracy: 0.1592
# Epoch 12/20
# 19/19 [==============================] - 70s 4s/step - loss: 1.2526 - accuracy: 0.6133 - val_loss: 2.9868 - val_accuracy: 0.1975
# Epoch 13/20
# 19/19 [==============================] - 70s 4s/step - loss: 1.1138 - accuracy: 0.6533 - val_loss: 2.9348 - val_accuracy: 0.1529
# Epoch 14/20
# 19/19 [==============================] - 74s 4s/step - loss: 0.9342 - accuracy: 0.7533 - val_loss: 2.9174 - val_accuracy: 0.1975
# Epoch 15/20
# 19/19 [==============================] - 71s 4s/step - loss: 0.8066 - accuracy: 0.7667 - val_loss: 2.9182 - val_accuracy: 0.1847
# Epoch 16/20
# 19/19 [==============================] - 70s 4s/step - loss: 0.6500 - accuracy: 0.8200 - val_loss: 3.1276 - val_accuracy: 0.2293
# Epoch 17/20
# 19/19 [==============================] - 70s 4s/step - loss: 0.5936 - accuracy: 0.8267 - val_loss: 3.3006 - val_accuracy: 0.2102
# Epoch 18/20
# 19/19 [==============================] - 71s 4s/step - loss: 0.5064 - accuracy: 0.9067 - val_loss: 3.1369 - val_accuracy: 0.2229
# Epoch 19/20
# 19/19 [==============================] - 70s 4s/step - loss: 0.3940 - accuracy: 0.9267 - val_loss: 3.5399 - val_accuracy: 0.1975
# Epoch 20/20
# 19/19 [==============================] - 70s 4s/step - loss: 0.3503 - accuracy: 0.9333 - val_loss: 3.2087 - val_accuracy: 0.2166

# %%
model.save('bird.h5')

# %%
from tensorflow.keras.preprocessing import image

# %%
output = ['rebimg','wcrsrt','jglowl','ibicrw','mgprob','hsparo',
         'indvul','himgri','himbul','gretit','hilpig','cbrtsh',
         'cmnmyn','bonegl','brhkyt','blasti']
print(output)
# Out:
# ['rebimg', 'wcrsrt', 'jglowl', 'ibicrw', 'mgprob', 'hsparo', 'indvul', 'himgri', 'himbul', 'gretit', 'hilpig', 'cbrtsh', 'cmnmyn', 'bonegl', 'brhkyt', 'blasti']

# %%
#test 1
img1 = image.load_img("/content/jglowl.jpg",target_size=(120,120))
img1 = image.img_to_array(img1)
img1 = np.expand_dims(img1,axis=0)
pred = np.argmax(model.predict(img1))
print(pred)
print(output[pred])
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 2
# jglowl

# %%
#test2
img2 = image.load_img("/content/mgprob.jpg",target_size=(120,120))
img2 = image.img_to_array(img2)
img2 = np.expand_dims(img2,axis=0)
pred = np.argmax(model.predict(img2))
print(pred)
print(output[pred])
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 2
# jglowl

# %%
#test3
img3 = image.load_img("//content/_D32_13515.jpg",target_size=(120,120))
img3 = image.img_to_array(img3)
img3 = np.expand_dims(img3,axis=0)
pred = np.argmax(model.predict(img3))
print(pred)
print(output[pred])
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 2
# jglowl

# %% [markdown]
# ### ***CNN with BatchNormalization and Dropout***

# %%
model = Sequential([
    Convolution2D(12,(3,3),activation = 'relu',input_shape=(120,120,3)),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.2),
    Convolution2D(24,(3,3),activation = 'relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.2),
    Convolution2D(36,(3,3),activation = 'relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),
    Dropout(0.2),
    Flatten(),
    Dense(62,activation = 'relu'),
    BatchNormalization(),
    Dropout(0.1),
    Dense(32,activation = 'relu'),
    Dense(16,activation = 'relu'),
    Dense(16,activation = 'softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 118, 118, 12)      336
#
#  batch_normalization_20 (Bat  (None, 118, 118, 12)     48
#  chNormalization)
#
#  max_pooling2d_20 (MaxPoolin  (None, 59, 59, 12)       0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 59, 59, 12)        0
#
#  conv2d_25 (Conv2D)          (None, 57, 57, 24)        2616
#
#  batch_normalization_21 (Bat  (None, 57, 57, 24)       96
#  chNormalization)
#
#  max_pooling2d_21 (MaxPoolin  (None, 28, 28, 24)       0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 28, 28, 24)        0
#
#  conv2d_26 (Conv2D)          (None, 26, 26, 36)        7812
#
#  batch_normalization_22 (Bat  (None, 26, 26, 36)       144
#  chNormalization)
#
#  max_pooling2d_22 (MaxPoolin  (None, 13, 13, 36)       0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 13, 13, 36)        0
#
#  flatten_10 (Flatten)        (None, 6084)              0
#
#  dense_30 (Dense)            (None, 62)                377270
#
#  batch_normalization_23 (Bat  (None, 62)               248
#  chNormalization)
#
#  dropout_23 (Dropout)        (None, 62)                0
#
#  dense_31 (Dense)            (None, 32)                2016
#
#  dense_32 (Dense)            (None, 16)                528
#
#  dense_33 (Dense)            (None, 16)                272
#
# =================================================================
# Total params: 391,386
# Trainable params: 391,118
# Non-trainable params: 268
# _________________________________________________________________

# %%
train.class_indices
# Out:
# {'blasti': 0,
#  'bonegl': 1,
#  'brhkyt': 2,
#  'cbrtsh': 3,
#  'cmnmyn': 4,
#  'gretit': 5,
#  'hilpig': 6,
#  'himbul': 7,
#  'himgri': 8,
#  'hsparo': 9,
#  'indvul': 10,
#  'jglowl': 11,
#  'lbicrw': 12,
#  'mgprob': 13,
#  'rebimg': 14,
#  'wcrsrt': 15}

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='categorical_crossentropy')

# %%
model_fit = model.fit(train,epochs =20,
                     validation_data = test ,batch_size=5)
# Out:
# Epoch 1/20
# 19/19 [==============================] - 77s 4s/step - loss: 2.8961 - accuracy: 0.1000 - val_loss: 2.8859 - val_accuracy: 0.0828
# Epoch 2/20
# 19/19 [==============================] - 72s 4s/step - loss: 2.5086 - accuracy: 0.2067 - val_loss: 3.4501 - val_accuracy: 0.0446
# Epoch 3/20
# 19/19 [==============================] - 71s 4s/step - loss: 2.3536 - accuracy: 0.3133 - val_loss: 4.1100 - val_accuracy: 0.0446
# Epoch 4/20
# 19/19 [==============================] - 71s 4s/step - loss: 2.2357 - accuracy: 0.3600 - val_loss: 4.9817 - val_accuracy: 0.0446
# Epoch 5/20
# 19/19 [==============================] - 70s 4s/step - loss: 2.1618 - accuracy: 0.3667 - val_loss: 5.8004 - val_accuracy: 0.0255
# Epoch 6/20
# 19/19 [==============================] - 71s 4s/step - loss: 2.2175 - accuracy: 0.3600 - val_loss: 5.6151 - val_accuracy: 0.0573
# Epoch 7/20
# 19/19 [==============================] - 70s 4s/step - loss: 1.9809 - accuracy: 0.4200 - val_loss: 4.7141 - val_accuracy: 0.0573
# Epoch 8/20
# 19/19 [==============================] - 71s 4s/step - loss: 1.9061 - accuracy: 0.4400 - val_loss: 4.7809 - val_accuracy: 0.0573
# Epoch 9/20
# 19/19 [==============================] - 75s 4s/step - loss: 1.8088 - accuracy: 0.4933 - val_loss: 4.9598 - val_accuracy: 0.0573
# Epoch 10/20
# 19/19 [==============================] - 70s 4s/step - loss: 1.7233 - accuracy: 0.4867 - val_loss: 5.2217 - val_accuracy: 0.0573
# Epoch 11/20
# 19/19 [==============================] - 71s 4s/step - loss: 1.7165 - accuracy: 0.5200 - val_loss: 5.5495 - val_accuracy: 0.0573
# Epoch 12/20
# 19/19 [==============================] - 71s 4s/step - loss: 1.6672 - accuracy: 0.4867 - val_loss: 4.1598 - val_accuracy: 0.1210
# Epoch 13/20
# 19/19 [==============================] - 71s 4s/step - loss: 1.6714 - accuracy: 0.5400 - val_loss: 4.0399 - val_accuracy: 0.0955
# Epoch 14/20
# 19/19 [==============================] - 71s 4s/step - loss: 1.6247 - accuracy: 0.5200 - val_loss: 4.4353 - val_accuracy: 0.0637
# Epoch 15/20
# 19/19 [==============================] - 72s 4s/step - loss: 1.5263 - accuracy: 0.5467 - val_loss: 4.6650 - val_accuracy: 0.0637
# Epoch 16/20
# 19/19 [==============================] - 76s 4s/step - loss: 1.3459 - accuracy: 0.5667 - val_loss: 4.3517 - val_accuracy: 0.0701
# Epoch 17/20
# 19/19 [==============================] - 73s 4s/step - loss: 1.3901 - accuracy: 0.5667 - val_loss: 4.5790 - val_accuracy: 0.0637
# Epoch 18/20
# 19/19 [==============================] - 70s 4s/step - loss: 1.3040 - accuracy: 0.6000 - val_loss: 4.2602 - val_accuracy: 0.1019
# Epoch 19/20
# 19/19 [==============================] - 71s 4s/step - loss: 1.2760 - accuracy: 0.6000 - val_loss: 4.5002 - val_accuracy: 0.0764
# Epoch 20/20
# 19/19 [==============================] - 74s 4s/step - loss: 1.0965 - accuracy: 0.6600 - val_loss: 3.9948 - val_accuracy: 0.0828

# %%
#test 1
img1 = image.load_img("/content/blasti.jpg",target_size=(120,120))
img1 = image.img_to_array(img1)
img1 = np.expand_dims(img1,axis=0)
pred = np.argmax(model.predict(img1))
print(pred)
print(output[pred])
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 2
# jglowl

# %%
#test2
img2 = image.load_img("/content/mgprob.jpg",target_size=(120,120))
img2 = image.img_to_array(img2)
img2 = np.expand_dims(img2,axis=0)
pred = np.argmax(model.predict(img2))
print(pred)
print(output[pred])
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 2
# jglowl

# %%
#test3
img3 = image.load_img("//content/_D32_13515.jpg",target_size=(120,120))
img3 = image.img_to_array(img3)
img3 = np.expand_dims(img3,axis=0)
pred = np.argmax(model.predict(img3))
print(pred)
print(output[pred])
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 2
# jglowl
